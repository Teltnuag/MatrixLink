# %%
# %load_ext autoreload
# %autoreload 1
# %aimport Utils
# %aimport MatrixLinkGenerator
import tensorflow as tf
# physical_devices = tf.config.list_physical_devices('GPU')
# tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)
# import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"]="4"
import random
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
np.set_printoptions(linewidth=np.inf)
from obspy import UTCDateTime
import datetime
import json
import pickle
import matplotlib.pyplot as plt
import math
from geographiclib.geodesic import Geodesic
from scipy.cluster.hierarchy import ward, fcluster
from scipy.spatial.distance import pdist, squareform
from Utils import trainingResults
# plt.rcParams['figure.figsize'] = [50, 200]
plt.rcParams['figure.figsize'] = [16, 12]
params = json.loads('''{
    "extents": {
        "s1": {
            "latMin": 22.0,
            "latMax": 40.0,
            "lonMin": 33.0,
            "lonMax": 62.0
        }
    },
    "location": "s1",
    "maxDepth": 50.0,
    "maxStationElevation": 0.5,
    "trainingGeneratorSourceFile": "./Training/Inputs/S1 00.gz",
    "trainingEventsFile": "./Training/Event Files/S1 Events 22-40-33-62 3+ Arrivals 120 TimeNorm.npz",
    "validationGeneratorSourceFile": "./Inputs/S1 00.gz",
    "validationEventsFile": "./Training/Event Files/S1 Events 22-40-33-62 3+ Arrivals 120 TimeNorm.npz",
    "arrivalProbsFile": "./Training/RSTT Model/S1 Dropouts.npy",
    "stationFile": "./Archive/Stations/S1 Station List.txt",
    "arrivalProbMods": {
        "Pg": 7.0,
        "Pn": 4.5,
        "Sg": 7.0,
        "Sn": 25.0
    },
    "eventsPerExample": {
        "min": 1,
        "max": 4
    },
    "stationsPerBatch": {
        "min": 45,
        "max": 55
    },
    "timeShifts": {
        "min": -0.50,
        "max": 0.50
    },
    "batchSize": 1000,
    "samplesPerEpoch": 1000000,
    "validationSamplesPerEpoch": 250000,
    "epochs": 400,
    "model": "./Models/E098 L0.0973 A0.9724 P0.9510 R0.9575 HL81.7 VL0.0323 VA0.9810 VP0.9751 VR0.9773 VHL46.7.h5",
    "evalInFile": "./Inputs/S1 00.gz",
    "evalOutFile": "./Training/Evaluation.gz",
    "prlEvalOutFile": "./Training/PRL Evaluation.gz",
    "maxArrivals": 50,
    "minArrivals": 3,
    "maxNoise": 0.20,
    "clusterStrength": 0.9,
    "timeNormalize": 120,
    "associationWindow": 300,
    "evalWindow": 10.0,
    "phases": {
        "Pg": 0, "PcP": 0, "Pb": 0,
        "P": 1, "Pn": 1,
        "S": 2, "Sg": 2, "ScP": 2, "Lg": 2, "Sb": 2,
        "Sn": 3
    },
    "modelArch": {
        "dense": [32, 32, 64, 128, 128],
        "transformers": [256, 256],
        "heads": 4,
        "dense2": [128, 128, 128],
        "grus": [256, 256]
    }
}''')
tf.config.list_physical_devices()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
# stationList = np.genfromtxt('./Archive/Stations/S1 Station List.txt', delimiter=' ')[:,2:]
stationList[np.random.randint(stationList.shape[0], size=5), :]
# Out:
# array([[ 35.6203  ,  51.495   ,   1.161   ],
#        [ 37.6593  ,  56.0893  ,   0.87    ],
#        [ 35.437901,  51.275799,   1.138   ],
#        [ 35.9078  ,  51.1259  ,   2.13    ],
#        [ 36.207   ,  53.6837  ,   2.161   ]])

# %%
import numpy as np
import pandas as pd
from obspy import UTCDateTime as dt
import random
import rstt
from copy import deepcopy
from collections import deque
import math
modelPath = "./Training/RSTT Model/pdu202009Du.geotess"
phases = ['Pg','Pn','Lg','Sn']

def generateEventFile(params, trainingSet = False):
    if trainingSet:
        eventsFile = params['trainingEventsFile']
        generatorFile = params['trainingGeneratorSourceFile']
    else:
        eventsFile = params['validationEventsFile']
        generatorFile = params['validationGeneratorSourceFile']
    try:
        events = np.load(eventsFile, allow_pickle=True)['events'].flatten()[0]
        print("Training events loaded.") if trainingSet else print("Validation events loaded.")
    except:
        print("Events not loaded. Building from scratch.")
        extents = np.array(list(params['extents'][params['location']].values())+[params['maxDepth'],params['maxStationElevation']])
        latRange = abs(extents[1] - extents[0])
        lonRange = abs(extents[3] - extents[2])
        timeNormalize = params['timeNormalize']
        phases = params['phases']
        events = {}
        inputArrivals = pd.read_pickle(generatorFile)
        groupedEvents = (inputArrivals.groupby('EVID').filter(lambda x: len(x) >= params['minArrivals'])).groupby('EVID')
        count = 0
        for eid, arrivals in groupedEvents:
            count += 1
            print("\rBuilding event list: " + str(count) + ' / ' + str(len(groupedEvents)), end='')
            eventArrivals = []
            first = dt(arrivals.TIME.min())
            evtime = -(first - dt(arrivals.EV_TIME.min())) / timeNormalize
            for i, arrival in arrivals.iterrows():
                thisArrival = [abs((arrival.ST_LAT - extents[0]) / latRange), # normalized station lat
                               abs((arrival.ST_LON - extents[2]) / lonRange), # normalized station lon
                               ((dt(arrival.TIME) - first) / timeNormalize),  # normalized arrival time
                               phases[arrival.PHASE],                         # phase
                               1.,                                            # valid arrival flag
                               5.0 / timeNormalize,                           # arrival uncertainty
                               0.9,                                           # retention rate when dropping some arrivals
                               abs((arrival.EV_LAT - extents[0]) / latRange), # normalized event lat
                               abs((arrival.EV_LON - extents[2]) / lonRange), # normalized event lon
                               arrival.EV_DEPTH / extents[4],                 # normalized event depth
                               evtime]                                        # normalized event time (relative to first arrival)
                eventArrivals.append(thisArrival)
            events[eid] = np.array(eventArrivals)
        np.savez_compressed(eventsFile, events=events)
        print()
    eventList = list(events.keys())
    return events, eventList

def buildAssociationMatrix(evids):
    L = np.zeros((len(evids), len(evids))) + 99
    sparse_evids = evids[evids>=0]
    l = np.ones((len(sparse_evids), len(sparse_evids))) * sparse_evids.reshape((-1, 1))
    L[:len(sparse_evids), :len(sparse_evids)] = (l == l.T) * 1
    return L

def synthesizeEventsFromEventFile(params, events, eventList, trainingSet = False):
    maxArrivals = params['maxArrivals']
    minTimeShift = params['timeShifts']['min']
    maxTimeShift = params['timeShifts']['max']
    minEvents = params['eventsPerExample']['min']
    maxEvents = params['eventsPerExample']['max']+1 # because using in np.random.randint
    dropFactor = 0.0
    batchSize = params['batchSize']

    while True:
        X = []
        Y = []
        example = 0
        while example < batchSize:
            #Setup - choose random events, with the first being the primary event
            numEvents = np.random.randint(minEvents, maxEvents)
            chosenEvents = random.sample(eventList, numEvents)
            timeShifts = np.random.uniform(minTimeShift, maxTimeShift, size=numEvents-1)
            for i in range(0, len(chosenEvents)):
                thisEvent = events[chosenEvents[i]]
                #Randomly drop some picks from the event
                if trainingSet:
                    drops = thisEvent[:,6]
                    drops = drops + dropFactor*(1-drops) if dropFactor > 0 else drops*(1+dropFactor)
                    drops = np.random.binomial(1,drops)
                    idx = np.where(drops==1)[0]
                    thisEvent = thisEvent[idx,:]
                if i == 0:
                    sequence = thisEvent
                    sequence[:,4] = i
                else:
                    #Add the picks from this event
                    currentLength = len(sequence)
                    sequence = np.append(sequence, thisEvent, axis=0)
                    #Shift the starting time of this event
                    sequence[currentLength:currentLength+len(thisEvent),[2,10]] += timeShifts[i-1]
                    sequence[currentLength:currentLength+len(thisEvent),4] = i

            #Add random arrival time errors, except for the first pick of the primary event
            if trainingSet:
                timeShifts = np.random.uniform(-sequence[1:,5], sequence[1:,5])
                sequence[1:,2] += timeShifts

            #Sort by arrival time, drop picks with negative arrival times
            idx = np.argsort(sequence[:,2])
            remove = len(np.where((sequence[:,2] < 0))[0])
            idx = idx[remove:]
            sequence = sequence[idx,:]
            if len(sequence) == 0: #We lost all the valid arrivals, so scrap this training example
                continue

            #Make labels array
            labels = buildAssociationMatrix(sequence[:,4])

            #Reset primary event times
            ones = np.where(labels[0]==1)
#             if len(ones[0]) == 0: #We lost all the valid arrivals, so scrap this training example
#                 continue
            sequence[ones,2] -= sequence[ones,2][0][0]
            idx = np.argsort(sequence[:,2])

            #Truncate picks over maximum allowed
            idx = idx[:maxArrivals]
            sequence = sequence[idx,:]
            labels = labels[idx,:maxArrivals]

            sequence[:,4] = 1.
            #Pad the end if not enough picks were selected
            padding = maxArrivals - len(sequence)
            if padding > 0:
                labels = np.pad(labels, (0,maxArrivals-len(labels)))
                sequence_ = np.zeros((maxArrivals, 11))
                sequence_[sequence.shape[0]:,2] = 0.0
                sequence_[:sequence.shape[0], :] = sequence
                sequence = sequence_
            X.append(sequence)
            Y.append(labels)
            example += 1
            
        #Yield these training examples
        X = np.array(X)
#         Y = {"association": np.array(Y), "location": X[:,:,[7,8]], "depth": X[:,:,9], "time": X[:,:,10]}
        Y = {"association": np.array(Y), "location": X[:,:,[7,8]]}
        X = {"phase": X[:,:,3], "numerical_features": X[:,:,[0,1,2,4]]}
        yield X, Y

def synthesizeEvents(params):
    def get_TT(srcLatDeg, srcLonDeg, srcDepKm, rcvLatDeg, rcvLonDeg, rcvDepKm, phase, slbm):
        phase = phases[phase]
        # create a great circle from source to the receiver
        slbm.createGreatCircle(phase,
            rstt.deg2rad(srcLatDeg),
            rstt.deg2rad(srcLonDeg),
            srcDepKm,
            rstt.deg2rad(rcvLatDeg),
            rstt.deg2rad(rcvLonDeg),
            rcvDepKm)
        # get the distance and travel time from source --> receiver
        travelTimeSec = slbm.getTravelTime()   # compute travel time (sec)
        # get the travel time uncertainty
        travelTimeUncertSec   = slbm.getTravelTimeUncertainty()
        return travelTimeSec, travelTimeUncertSec
        
    def haversine(lat1, lon1, lat2, lon2):
        """
        Calculate the great circle distance between every combination of two points
        on the earth (specified in decimal degrees)
        """
        lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
        lat1 = lat1[:, np.newaxis]
        lon1 = lon1[:, np.newaxis]
        
        dlat = lat2 - lat1
        dlon = lon2 - lon1
    
        a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2
        km = 2 * np.arcsin(np.sqrt(a)) * 6378.1
        bucket = (km/100).astype(int)
        bucket = np.clip(bucket, 0, 11)
        return bucket

    # instantiate an RSTT object
    slbm = rstt.SlbmInterface()
    # load the velocity model
    slbm.loadVelocityModel(modelPath)
    # load the arrival probabilities
    arrivalProbs = np.load(params['arrivalProbsFile']) # Phase (Pg, Pn, Lg, Sn), Distance (0-11), Magnitude (0-5)
    
    # read in all the parameters first to avoid redundant lookups. Really just more readable
    timeNormalize = params['timeNormalize']
    batchSize = params['batchSize']
    maxArrivals = params['maxArrivals']
    minTimeShift = params['timeShifts']['min']
    maxTimeShift = params['timeShifts']['max']
    totalEvents = int(batchSize/3)
    minEvents = params['eventsPerExample']['min']
    maxEvents = params['eventsPerExample']['max']+1 # because using in np.random.randint
    minStations = params['stationsPerBatch']['min']
    maxStations = params['stationsPerBatch']['max']+1 # because using in np.random.randint
    maxNoise = maxArrivals*params['maxNoise']
    extents = np.array(list(params['extents'][params['location']].values())+[params['maxDepth'],params['maxStationElevation']])
    latRange = abs(extents[1] - extents[0])
    lonRange = abs(extents[3] - extents[2])
    arrivalProbs = np.load(params['arrivalProbsFile'])/100 # Phase (Pg, Pn, Lg, Sn), Distance (0-11), Magnitude (0-5)
    arrivalProbs[0] = np.clip(arrivalProbs[0]*params['arrivalProbMods']['Pg'],0,1)
    arrivalProbs[1] = np.clip(arrivalProbs[1]*params['arrivalProbMods']['Pn'],0,1)
    arrivalProbs[2] = np.clip(arrivalProbs[2]*params['arrivalProbMods']['Sg'],0,1)
    arrivalProbs[3] = np.clip(arrivalProbs[3]*params['arrivalProbMods']['Sn'],0,1)
    
    def processEvents(events):
        numEvents = np.random.randint(minEvents, maxEvents, batchSize)
        examplesList = [random.sample(range(len(events)), evs) for evs in numEvents]
        examples = [[deepcopy(events[e]) for e in examplesList[ex]] for ex in range(len(examplesList))]

        # generate noise
        numNoise = np.random.randint(0, maxNoise, batchSize)
        totalNoise = np.sum(numNoise)
        noise = np.zeros((totalNoise, 9))
        noise[:,[0,1,5,6]] = stations[np.random.randint(0, numStations, totalNoise)][:,[0,1,0,1]] # location of noise arrivals = station location
        noise[:,2] = np.random.uniform(0, 1, totalNoise)
        noise[:,3] = np.random.choice([0.,1.,2.,3.], size=totalNoise, p=[.125,.74,.115,.02])
        noiseUsed = 0

        # generate all the amounts to shift events and phases around
        timeMods = np.random.uniform(minTimeShift,maxTimeShift,np.sum(numEvents-1))
        timeModsUsed = 0

        X = np.zeros((batchSize, maxArrivals, 5))
        Ya = np.zeros((batchSize, maxArrivals, maxArrivals)) # Association matrix labels
        Yl = np.zeros((batchSize, maxArrivals, 4)) # Location/depth/time labels
        for i in range(batchSize):
            example = examples[i]
            ev = 0
            evids = deque([ev]*len(example[ev]))
            for event in example[1:]:
                ev += 1
                evids.extend([ev]*len(example[ev]))
                event[:,[2,8]] += timeMods[timeModsUsed]
                timeModsUsed += 1
    
            # Add noise
            example.append(noise[noiseUsed:noiseUsed+numNoise[i]])
            noiseUsed += numNoise[i]
            examples[i] = np.concatenate(example)
            ev += 1
            evids.extend(np.array(range(ev,ev+numNoise[i])))

            # examples[i][1:,2] += examples[i][1:,4]*np.random.normal(0,0.25,len(examples[i][1:]))
            examples[i][:,4] = evids
            idx = np.argsort(examples[i][:,2])
            start = np.argmax(idx == 0)
            idx = idx[start:start+maxArrivals]
            examples[i] = examples[i][idx]
            Ya[i][:len(examples[i]),:len(examples[i])] = buildAssociationMatrix(examples[i][:,4])
            Yl[i][:len(examples[i]),:] = examples[i][:,[5,6,7,8]]
            examples[i][:,4] = 1.
            X[i][:len(examples[i])] = examples[i][:,:5]

        X = {"phase": X[:,:,3], "numerical_features": X[:,:,[0,1,2,4]]}
#         Y = {"association": Ya, "location": Yl[:,:,[0,1]], "depth": Yl[:,:,2], "time": Yl[:,:,3]}
        Y = {"association": Ya, "location": Yl[:,:,[0,1]]}
        return X, Y

    while(True):
        # Create a random numbers of events per training example...
        # ...and a random numbers of receiving stations to be used for each training example
        numStations = np.random.randint(minStations, maxStations)
        genEvents = np.zeros((totalEvents, 6))
        stations = np.zeros((numStations, 6))
        genEvents[:,0:2] = np.random.rand(totalEvents, 2) # [evLat, evLon, evDepth]
        genEvents[:,3] = abs(np.random.normal(loc=.2, scale=.25, size=totalEvents))
        stations[:,0:3] = np.random.rand(numStations, 3) # [stLat, stLon, stDepth]

        # Calculate the denormalized event and station latitudes
        genEvents[:,3] = genEvents[:,0]*latRange + extents[0]
        stations[:,3] = stations[:,0]*latRange + extents[0]
        # Calculate the denormalized event and station longitudes
        genEvents[:,4] = genEvents[:,1]*lonRange + extents[2]
        stations[:,4] = stations[:,1]*lonRange + extents[2]
        # Calculate the denormalized event and stations depths
        genEvents[:,5] = genEvents[:,2]*extents[4]
        stations[:,5] = -stations[:,2]*extents[5] # because it's elevation, I think

        # Generate random magnitudes (as buckets for looking up in the arrival probability table)
        # Calculate the distances between stations and events and get the buckets for looking up in the probability table
        mags = np.random.randint(0, 6, totalEvents)
        dists = haversine(genEvents[:,3],genEvents[:,4],stations[:,3],stations[:,4]) # distance buckets as dists[event, station]

        # Lookup retention values for each training example, phase, event, station
        arrivals = arrivalProbs[:,dists,mags[:,np.newaxis]]
        arrivals = np.random.binomial(1,arrivals) # arrivals[phase][event][station]
        arrivals = np.argwhere(arrivals==1)
        evids, counts = np.unique(arrivals[:,1], return_counts=True) # Ensure there are at least a few arrivals for each event
        evids = evids[np.where(counts >= params['minArrivals'])]
        arrivals = arrivals[np.isin(arrivals[:,1],evids)]

        # Build the events list
        events = np.full((len(arrivals),10),np.nan) # normal station lat, normal station lon, travel time, phase, travel time uncertainty, event lat, event lon, event depth, event time, event id
        currentPhase = 0
        for arrival in range(len(arrivals)):
            ph, ev, st = arrivals[arrival]
            try:
                tt, uncert = get_TT(genEvents[ev,3],genEvents[ev,4],genEvents[ev,5],stations[st,3],stations[st,4],stations[st,5],ph,slbm)
                tt += uncert*np.random.normal(0,0.25) # Add random arrival errors
                events[currentPhase] = [stations[st,0], stations[st,1], tt, ph, uncert, genEvents[ev,0], genEvents[ev,1], genEvents[ev,2], 0, ev]
                currentPhase += 1
            except Exception as e:
        #                 print(e)
                pass
        events = events[~np.any(np.isnan(events), axis=1)] # Remove NaNs (from failed TT calculations)
        events[:,[2,4]] /= timeNormalize # Normalize time values
        events = events[np.lexsort((events[:,2], events[:,-1]))] # Sort by event id, then by travel time

        events = np.split(events[:,:-1], np.unique(events[:,-1], return_index=True)[1][1:]) # arrivals as an array of events
        for event in events:
            event[:,[2,8]] -= event[0,2] # convert travel time to arrival time, retain event time TODO: can this be done vectorized?
        yield processEvents(events)

# %%
#MatrixLinkTrainer
import tensorflow as tf
import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.layers import Input, Embedding, Reshape, concatenate, Dense, Bidirectional, GRU, MultiHeadAttention, LayerNormalization
from tensorflow.keras.initializers import RandomNormal
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.callbacks import EarlyStopping, CSVLogger
import logging
import json
# from MatrixLinkGenerator import generateEventFile, synthesizeEvents, synthesizeEventsFromEventFile
from Utils import nzBCE, nzMSE1, nzMSE2, nzHaversine, nzDepth, nzTime, nzAccuracy, trainingResults

@tf.autograph.experimental.do_not_convert
def MatrixLink(params):
    logging.getLogger("tensorflow").setLevel(logging.ERROR)
    def buildModel(modelArch):
        outputs = []
        inputs = []
        numericalInputs = Input(shape=(None,4), name='numerical_features')
        outputs.append(numericalInputs)
        inputs.append(numericalInputs)
        categoricalInputs = Input(shape=(None,1), name='phase')
        embed = Embedding(4, 2, trainable=True, embeddings_initializer=RandomNormal())(categoricalInputs)
        embed = Reshape(target_shape=(-1,2))(embed)
        outputs.append(embed)
        inputs.append(categoricalInputs)
        outputs = concatenate(outputs)

        def TransformerBlock(inputs, embed_dim, ff_dim, num_heads=2, rate=0.1, eps=1e-6):
            attn_output = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)(inputs, inputs)
#             attn_output = Dropout(rate)(attn_output)
            out1 = LayerNormalization(epsilon=eps)(inputs + attn_output)
            ffn_output = Dense(ff_dim, activation="relu")(out1)
            ffn_output = Dense(embed_dim)(ffn_output)
#             ffn_output = Dropout(rate)(ffn_output)
            return LayerNormalization(epsilon=eps)(out1 + ffn_output) 

        for d1Units in modelArch['dense']:
            outputs = Dense(units=d1Units, activation=tf.nn.relu)(outputs)
        transformerOutputs = outputs
        gruOutputs = outputs

        for tUnits in modelArch['transformers']:
            transformerOutputs = TransformerBlock(transformerOutputs, d1Units, tUnits, modelArch['heads'])
        for gUnits in modelArch['grus']:
            gruOutputs = Bidirectional(GRU(gUnits, return_sequences=True))(gruOutputs)

        outputs = concatenate([transformerOutputs, gruOutputs], axis=2)
        for tUnits in modelArch['transformers']:
            outputs = TransformerBlock(outputs, d1Units+gUnits*2, tUnits, modelArch['heads'])
        
        association = Dense(units=params['maxArrivals'], activation=tf.nn.sigmoid, name='association')(outputs)
        location = Dense(units=2, name='location')(outputs)
        # depth = Dense(units=1, name='depth')(outputs)
        # time = Dense(units=1, name='time')(outputs)
        
        # model = Model(inputs=inputs, outputs=[association, location, depth, time])
        model = Model(inputs=inputs, outputs=[association, location])
        # losses = { 'association': nzBCE, 'location': nzMSE2, 'depth': nzMSE1, 'time': nzMSE1 }
        losses = { 'association': nzBCE, 'location': nzMSE2 }
        # weights = { 'association': 1.0, 'location': 6.0, 'depth': 0.075, 'time': 1.0 }
        weights = { 'association': 1.0, 'location': 10.0 }
        metrics = { 'association': [nzAccuracy, Precision(name='precision'), Recall(name='recall')],
                    'location': nzHaversine }
                    # 'depth': nzDepth,
                    # 'time': nzTime }
        model.compile(optimizer=Adam(clipnorm=0.00001), loss=losses, loss_weights=weights, metrics=metrics)
        return model

    model = buildModel(params['modelArch'])
    try:
        model.load_weights(params['model'])
        print("Loaded previous weights.")
    except Exception as e:
        print(e)
        print("No previous weights loaded.")
    print(model.summary())
    return model

class saveCb(Callback):
    def on_train_begin(self, logs=None):
        self.best = 100.
    def on_epoch_end(self, epoch, logs=None):
        if logs['loss'] < self.best:
            self.best = logs['loss']
            print('Saving best model with loss', self.best)
            # modelName = 'E%03d L%.4f A%.4f P%.4f R%.4f HL%.1f DL%.3f TL%.3f VL%.4f VA%.4f VP%.4f VR%.4f VHL%.1f VDL%.3f VTL%.3f.h5' %\
            #     (epoch, logs['loss'], logs['association_nzAccuracy'], logs['association_precision'], logs['association_recall'], logs['location_nzHaversine'], logs['depth_nzDepth'], logs['time_nzTime'],
            #      logs['val_loss'], logs['val_association_nzAccuracy'], logs['val_association_precision'], logs['val_association_recall'], logs['val_location_nzHaversine'], logs['val_depth_nzDepth'], logs['val_time_nzTime'])
            modelName = 'E%03d L%.4f A%.4f P%.4f R%.4f HL%.1f VL%.4f VA%.4f VP%.4f VR%.4f VHL%.1f.h5' %\
                (epoch, logs['loss'], logs['association_nzAccuracy'], logs['association_precision'], logs['association_recall'], logs['location_nzHaversine'], 
                 logs['val_loss'], logs['val_association_nzAccuracy'], logs['val_association_precision'], logs['val_association_recall'], logs['val_location_nzHaversine'])
            model.save("./Training/Models/Batch Error/"+modelName)

# %%
# tf.config.threading.set_intra_op_parallelism_threads(2)
# tf.config.threading.set_inter_op_parallelism_threads(2)

# trainingEvents, trainingEventList = generateEventFile(params, trainingSet=True)
validationEvents, validationEventList = generateEventFile(params)

# generator = synthesizeEventsFromEventFile(params, trainingEvents, trainingEventList, trainingSet=True)
generator = synthesizeEvents(params)
vgen = synthesizeEventsFromEventFile(params, validationEvents, validationEventList)
# vgen = synthesizeEvents(params)

model = MatrixLink(params)
history = model.fit(generator,
                 validation_data=vgen,
                 steps_per_epoch= params['samplesPerEpoch']/params['batchSize'],
                 validation_steps = params['validationSamplesPerEpoch']/params['batchSize'],
                 epochs=params['epochs'],
                 callbacks=[saveCb(), EarlyStopping(monitor='loss', patience=40), CSVLogger('./Training/Models/Batch Error/logs.csv', append = True)],
                 verbose=1)
trainingResults(np.genfromtxt('./Training/Models/Batch Error/logs.csv', delimiter=',', names=True))
# Out:
# Validation events loaded.
# Loaded previous weights.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# phase (InputLayer)              [(None, None, 1)]    0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, None, 1, 2)   8           phase[0][0]
# __________________________________________________________________________________________________
# numerical_features (InputLayer) [(None, None, 4)]    0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, None, 2)      0           embedding[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, None, 6)      0           numerical_features[0][0]
#                                                                  reshape[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 32)     224         concatenate[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 32)     1056        dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, None, 64)     2112        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, None, 128)    8320        dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, None, 128)    16512       dense_3[0][0]
# __________________________________________________________________________________________________
# multi_head_attention (MultiHead (None, None, 128)    263808      dense_4[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, None, 128)    0           dense_4[0][0]
#                                                                  multi_head_attention[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, None, 128)    256         tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, None, 256)    33024       layer_normalization[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, None, 128)    32896       dense_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, None, 128)    0           layer_normalization[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, None, 128)    256         tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_1 (MultiHe (None, None, 128)    263808      layer_normalization_1[0][0]
#                                                                  layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLam (None, None, 128)    0           layer_normalization_1[0][0]
#                                                                  multi_head_attention_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, None, 128)    256         tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, None, 256)    33024       layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, None, 128)    32896       dense_7[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLam (None, None, 128)    0           layer_normalization_2[0][0]
#                                                                  dense_8[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, None, 512)    592896      dense_4[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, None, 128)    256         tf.__operators__.add_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, None, 512)    1182720     bidirectional[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, 640)    0           layer_normalization_3[0][0]
#                                                                  bidirectional_1[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_2 (MultiHe (None, None, 640)    6561920     concatenate_1[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_4 (TFOpLam (None, None, 640)    0           concatenate_1[0][0]
#                                                                  multi_head_attention_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (None, None, 640)    1280        tf.__operators__.add_4[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, None, 256)    164096      layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, None, 640)    164480      dense_9[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_5 (TFOpLam (None, None, 640)    0           layer_normalization_4[0][0]
#                                                                  dense_10[0][0]
# __________________________________________________________________________________________________
# layer_normalization_5 (LayerNor (None, None, 640)    1280        tf.__operators__.add_5[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_3 (MultiHe (None, None, 640)    6561920     layer_normalization_5[0][0]
#                                                                  layer_normalization_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_6 (TFOpLam (None, None, 640)    0           layer_normalization_5[0][0]
#                                                                  multi_head_attention_3[0][0]
# __________________________________________________________________________________________________
# layer_normalization_6 (LayerNor (None, None, 640)    1280        tf.__operators__.add_6[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, None, 256)    164096      layer_normalization_6[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, None, 640)    164480      dense_11[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_7 (TFOpLam (None, None, 640)    0           layer_normalization_6[0][0]
#                                                                  dense_12[0][0]
# __________________________________________________________________________________________________
# layer_normalization_7 (LayerNor (None, None, 640)    1280        tf.__operators__.add_7[0][0]
# __________________________________________________________________________________________________
# association (Dense)             (None, None, 50)     32050       layer_normalization_7[0][0]
# __________________________________________________________________________________________________
# location (Dense)                (None, None, 2)      1282        layer_normalization_7[0][0]
# ==================================================================================================
# Total params: 16,283,772
# Trainable params: 16,283,772
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/400
# 1000/1000 [==============================] - 2189s 1s/step - loss: 0.0961 - association_loss: 0.0433 - location_loss: 0.0053 - association_nzAccuracy: 0.9727 - association_precision: 0.9518 - association_recall: 0.9580 - location_nzHaversine: 80.5132 - val_loss: 0.0334 - val_association_loss: 0.0172 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9811 - val_association_precision: 0.9738 - val_association_recall: 0.9788 - val_location_nzHaversine: 77.2803
# Saving best model with loss 0.09681124240159988
# Epoch 2/400
# 1000/1000 [==============================] - 1200s 1s/step - loss: 0.0965 - association_loss: 0.0438 - location_loss: 0.0053 - association_nzAccuracy: 0.9726 - association_precision: 0.9516 - association_recall: 0.9576 - location_nzHaversine: 80.6291 - val_loss: 0.0344 - val_association_loss: 0.0179 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9803 - val_association_precision: 0.9748 - val_association_recall: 0.9746 - val_location_nzHaversine: 45.8827
# Epoch 3/400
# 1000/1000 [==============================] - 1200s 1s/step - loss: 0.0975 - association_loss: 0.0439 - location_loss: 0.0054 - association_nzAccuracy: 0.9724 - association_precision: 0.9514 - association_recall: 0.9577 - location_nzHaversine: 81.9318 - val_loss: 0.0338 - val_association_loss: 0.0179 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9800 - val_association_precision: 0.9746 - val_association_recall: 0.9766 - val_location_nzHaversine: 50.7821
# Epoch 4/400
# 1000/1000 [==============================] - 1199s 1s/step - loss: 0.0972 - association_loss: 0.0438 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9514 - association_recall: 0.9573 - location_nzHaversine: 82.2560 - val_loss: 0.0351 - val_association_loss: 0.0186 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9796 - val_association_precision: 0.9736 - val_association_recall: 0.9739 - val_location_nzHaversine: 55.7384
# Epoch 5/400
# 1000/1000 [==============================] - 1199s 1s/step - loss: 0.0981 - association_loss: 0.0442 - location_loss: 0.0054 - association_nzAccuracy: 0.9722 - association_precision: 0.9508 - association_recall: 0.9571 - location_nzHaversine: 82.7035 - val_loss: 0.0322 - val_association_loss: 0.0170 - val_location_loss: 0.0015 - val_association_nzAccuracy: 0.9813 - val_association_precision: 0.9713 - val_association_recall: 0.9806 - val_location_nzHaversine: 71.2307
# Epoch 6/400
# 1000/1000 [==============================] - 1199s 1s/step - loss: 0.0973 - association_loss: 0.0441 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9512 - association_recall: 0.9570 - location_nzHaversine: 81.3370 - val_loss: 0.0343 - val_association_loss: 0.0173 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9813 - val_association_precision: 0.9744 - val_association_recall: 0.9792 - val_location_nzHaversine: 54.5443
# Epoch 7/400
# 1000/1000 [==============================] - 1200s 1s/step - loss: 0.0981 - association_loss: 0.0442 - location_loss: 0.0054 - association_nzAccuracy: 0.9722 - association_precision: 0.9509 - association_recall: 0.9568 - location_nzHaversine: 82.8719 - val_loss: 0.0337 - val_association_loss: 0.0185 - val_location_loss: 0.0015 - val_association_nzAccuracy: 0.9803 - val_association_precision: 0.9709 - val_association_recall: 0.9745 - val_location_nzHaversine: 51.2954
# Epoch 8/400
# 1000/1000 [==============================] - 1200s 1s/step - loss: 0.0979 - association_loss: 0.0441 - location_loss: 0.0054 - association_nzAccuracy: 0.9723 - association_precision: 0.9509 - association_recall: 0.9572 - location_nzHaversine: 82.4167 - val_loss: 0.0349 - val_association_loss: 0.0186 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9801 - val_association_precision: 0.9734 - val_association_recall: 0.9711 - val_location_nzHaversine: 58.2322
# Epoch 9/400
# 1000/1000 [==============================] - 1200s 1s/step - loss: 0.0979 - association_loss: 0.0440 - location_loss: 0.0054 - association_nzAccuracy: 0.9722 - association_precision: 0.9508 - association_recall: 0.9571 - location_nzHaversine: 83.2391 - val_loss: 0.0348 - val_association_loss: 0.0177 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9803 - val_association_precision: 0.9744 - val_association_recall: 0.9770 - val_location_nzHaversine: 62.7084
# Epoch 10/400
# 1000/1000 [==============================] - 1200s 1s/step - loss: 0.0986 - association_loss: 0.0445 - location_loss: 0.0054 - association_nzAccuracy: 0.9720 - association_precision: 0.9503 - association_recall: 0.9565 - location_nzHaversine: 82.2422 - val_loss: 0.0359 - val_association_loss: 0.0175 - val_location_loss: 0.0018 - val_association_nzAccuracy: 0.9809 - val_association_precision: 0.9752 - val_association_recall: 0.9764 - val_location_nzHaversine: 87.5594
# Epoch 11/400
# 1000/1000 [==============================] - 1200s 1s/step - loss: 0.0972 - association_loss: 0.0440 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9514 - association_recall: 0.9573 - location_nzHaversine: 81.7213 - val_loss: 0.0331 - val_association_loss: 0.0172 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9811 - val_association_precision: 0.9723 - val_association_recall: 0.9797 - val_location_nzHaversine: 47.7341
# Epoch 12/400
# 1000/1000 [==============================] - 1199s 1s/step - loss: 0.0985 - association_loss: 0.0443 - location_loss: 0.0054 - association_nzAccuracy: 0.9722 - association_precision: 0.9505 - association_recall: 0.9569 - location_nzHaversine: 83.1247 - val_loss: 0.0345 - val_association_loss: 0.0188 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9797 - val_association_precision: 0.9714 - val_association_recall: 0.9740 - val_location_nzHaversine: 48.2039
# Epoch 13/400
# 1000/1000 [==============================] - 1200s 1s/step - loss: 0.0972 - association_loss: 0.0439 - location_loss: 0.0053 - association_nzAccuracy: 0.9725 - association_precision: 0.9514 - association_recall: 0.9571 - location_nzHaversine: 81.4086 - val_loss: 0.0339 - val_association_loss: 0.0179 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9806 - val_association_precision: 0.9739 - val_association_recall: 0.9766 - val_location_nzHaversine: 55.4424
# Epoch 14/400
# 1000/1000 [==============================] - 1200s 1s/step - loss: 0.0974 - association_loss: 0.0440 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9513 - association_recall: 0.9573 - location_nzHaversine: 81.7880 - val_loss: 0.0358 - val_association_loss: 0.0182 - val_location_loss: 0.0018 - val_association_nzAccuracy: 0.9796 - val_association_precision: 0.9746 - val_association_recall: 0.9755 - val_location_nzHaversine: 72.0063
# Epoch 15/400
# 1000/1000 [==============================] - 1200s 1s/step - loss: 0.0980 - association_loss: 0.0440 - location_loss: 0.0054 - association_nzAccuracy: 0.9724 - association_precision: 0.9509 - association_recall: 0.9575 - location_nzHaversine: 83.0140 - val_loss: 0.0352 - val_association_loss: 0.0182 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9797 - val_association_precision: 0.9740 - val_association_recall: 0.9755 - val_location_nzHaversine: 63.0420
# Epoch 16/400
# 1000/1000 [==============================] - 1197s 1s/step - loss: 0.0976 - association_loss: 0.0439 - location_loss: 0.0054 - association_nzAccuracy: 0.9724 - association_precision: 0.9515 - association_recall: 0.9575 - location_nzHaversine: 81.6013 - val_loss: 0.0339 - val_association_loss: 0.0178 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9802 - val_association_precision: 0.9720 - val_association_recall: 0.9787 - val_location_nzHaversine: 54.6833
# Epoch 17/400
# 1000/1000 [==============================] - 1195s 1s/step - loss: 0.0973 - association_loss: 0.0438 - location_loss: 0.0054 - association_nzAccuracy: 0.9725 - association_precision: 0.9511 - association_recall: 0.9571 - location_nzHaversine: 81.3597 - val_loss: 0.0343 - val_association_loss: 0.0175 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9809 - val_association_precision: 0.9753 - val_association_recall: 0.9759 - val_location_nzHaversine: 54.4912
# Epoch 18/400
# 1000/1000 [==============================] - 1192s 1s/step - loss: 0.0978 - association_loss: 0.0441 - location_loss: 0.0054 - association_nzAccuracy: 0.9724 - association_precision: 0.9512 - association_recall: 0.9572 - location_nzHaversine: 82.0756 - val_loss: 0.0339 - val_association_loss: 0.0176 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9811 - val_association_precision: 0.9716 - val_association_recall: 0.9790 - val_location_nzHaversine: 61.6582
# Epoch 19/400
# 1000/1000 [==============================] - 1193s 1s/step - loss: 0.0978 - association_loss: 0.0441 - location_loss: 0.0054 - association_nzAccuracy: 0.9723 - association_precision: 0.9509 - association_recall: 0.9570 - location_nzHaversine: 81.5376 - val_loss: 0.0348 - val_association_loss: 0.0174 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9814 - val_association_precision: 0.9730 - val_association_recall: 0.9779 - val_location_nzHaversine: 57.7361
# Epoch 20/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0974 - association_loss: 0.0438 - location_loss: 0.0054 - association_nzAccuracy: 0.9724 - association_precision: 0.9515 - association_recall: 0.9575 - location_nzHaversine: 81.9894 - val_loss: 0.0365 - val_association_loss: 0.0188 - val_location_loss: 0.0018 - val_association_nzAccuracy: 0.9791 - val_association_precision: 0.9741 - val_association_recall: 0.9737 - val_location_nzHaversine: 58.6206
# Epoch 21/400
# 1000/1000 [==============================] - 1195s 1s/step - loss: 0.0974 - association_loss: 0.0439 - location_loss: 0.0054 - association_nzAccuracy: 0.9724 - association_precision: 0.9512 - association_recall: 0.9573 - location_nzHaversine: 81.6851 - val_loss: 0.0339 - val_association_loss: 0.0184 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9800 - val_association_precision: 0.9717 - val_association_recall: 0.9764 - val_location_nzHaversine: 51.3117
# Epoch 22/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0981 - association_loss: 0.0440 - location_loss: 0.0054 - association_nzAccuracy: 0.9723 - association_precision: 0.9511 - association_recall: 0.9573 - location_nzHaversine: 82.5175 - val_loss: 0.0335 - val_association_loss: 0.0174 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9809 - val_association_precision: 0.9738 - val_association_recall: 0.9789 - val_location_nzHaversine: 58.0246
# Epoch 23/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0977 - association_loss: 0.0439 - location_loss: 0.0054 - association_nzAccuracy: 0.9722 - association_precision: 0.9510 - association_recall: 0.9569 - location_nzHaversine: 82.0140 - val_loss: 0.0356 - val_association_loss: 0.0183 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9794 - val_association_precision: 0.9736 - val_association_recall: 0.9775 - val_location_nzHaversine: 60.5463
# Epoch 24/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0980 - association_loss: 0.0441 - location_loss: 0.0054 - association_nzAccuracy: 0.9722 - association_precision: 0.9510 - association_recall: 0.9572 - location_nzHaversine: 82.0027 - val_loss: 0.0343 - val_association_loss: 0.0177 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9804 - val_association_precision: 0.9724 - val_association_recall: 0.9787 - val_location_nzHaversine: 53.9611
# Epoch 25/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0966 - association_loss: 0.0439 - location_loss: 0.0053 - association_nzAccuracy: 0.9725 - association_precision: 0.9512 - association_recall: 0.9576 - location_nzHaversine: 81.0429 - val_loss: 0.0338 - val_association_loss: 0.0178 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9798 - val_association_precision: 0.9734 - val_association_recall: 0.9787 - val_location_nzHaversine: 46.6508
# Epoch 26/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0969 - association_loss: 0.0439 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9509 - association_recall: 0.9572 - location_nzHaversine: 81.2128 - val_loss: 0.0333 - val_association_loss: 0.0175 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9807 - val_association_precision: 0.9734 - val_association_recall: 0.9792 - val_location_nzHaversine: 68.4663
# Epoch 27/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0971 - association_loss: 0.0438 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9512 - association_recall: 0.9574 - location_nzHaversine: 81.7285 - val_loss: 0.0345 - val_association_loss: 0.0182 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9801 - val_association_precision: 0.9727 - val_association_recall: 0.9760 - val_location_nzHaversine: 57.2030
# Epoch 28/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0969 - association_loss: 0.0439 - location_loss: 0.0053 - association_nzAccuracy: 0.9725 - association_precision: 0.9513 - association_recall: 0.9576 - location_nzHaversine: 81.5073 - val_loss: 0.0326 - val_association_loss: 0.0170 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9817 - val_association_precision: 0.9730 - val_association_recall: 0.9795 - val_location_nzHaversine: 54.8866
# Epoch 29/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0974 - association_loss: 0.0439 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9510 - association_recall: 0.9573 - location_nzHaversine: 81.1633 - val_loss: 0.0352 - val_association_loss: 0.0178 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9807 - val_association_precision: 0.9726 - val_association_recall: 0.9769 - val_location_nzHaversine: 68.2887
# Epoch 30/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0972 - association_loss: 0.0439 - location_loss: 0.0053 - association_nzAccuracy: 0.9725 - association_precision: 0.9514 - association_recall: 0.9577 - location_nzHaversine: 81.1812 - val_loss: 0.0334 - val_association_loss: 0.0173 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9810 - val_association_precision: 0.9738 - val_association_recall: 0.9782 - val_location_nzHaversine: 53.3359
# Epoch 31/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0978 - association_loss: 0.0440 - location_loss: 0.0054 - association_nzAccuracy: 0.9723 - association_precision: 0.9512 - association_recall: 0.9571 - location_nzHaversine: 82.7315 - val_loss: 0.0350 - val_association_loss: 0.0185 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9797 - val_association_precision: 0.9738 - val_association_recall: 0.9741 - val_location_nzHaversine: 57.1130
# Epoch 32/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0973 - association_loss: 0.0441 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9511 - association_recall: 0.9567 - location_nzHaversine: 81.5083 - val_loss: 0.0335 - val_association_loss: 0.0177 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9806 - val_association_precision: 0.9730 - val_association_recall: 0.9775 - val_location_nzHaversine: 48.8107
# Epoch 33/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0977 - association_loss: 0.0441 - location_loss: 0.0054 - association_nzAccuracy: 0.9724 - association_precision: 0.9511 - association_recall: 0.9575 - location_nzHaversine: 82.6114 - val_loss: 0.0334 - val_association_loss: 0.0178 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9802 - val_association_precision: 0.9727 - val_association_recall: 0.9787 - val_location_nzHaversine: 52.4288
# Epoch 34/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0978 - association_loss: 0.0439 - location_loss: 0.0054 - association_nzAccuracy: 0.9723 - association_precision: 0.9511 - association_recall: 0.9571 - location_nzHaversine: 82.0461 - val_loss: 0.0368 - val_association_loss: 0.0184 - val_location_loss: 0.0018 - val_association_nzAccuracy: 0.9800 - val_association_precision: 0.9726 - val_association_recall: 0.9742 - val_location_nzHaversine: 64.9259
# Epoch 35/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0969 - association_loss: 0.0436 - location_loss: 0.0053 - association_nzAccuracy: 0.9725 - association_precision: 0.9515 - association_recall: 0.9573 - location_nzHaversine: 81.4907 - val_loss: 0.0332 - val_association_loss: 0.0176 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9808 - val_association_precision: 0.9735 - val_association_recall: 0.9766 - val_location_nzHaversine: 42.3942
# Epoch 36/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0973 - association_loss: 0.0439 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9515 - association_recall: 0.9572 - location_nzHaversine: 80.7670 - val_loss: 0.0327 - val_association_loss: 0.0175 - val_location_loss: 0.0015 - val_association_nzAccuracy: 0.9811 - val_association_precision: 0.9712 - val_association_recall: 0.9800 - val_location_nzHaversine: 54.9717
# Epoch 37/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0979 - association_loss: 0.0441 - location_loss: 0.0054 - association_nzAccuracy: 0.9723 - association_precision: 0.9509 - association_recall: 0.9569 - location_nzHaversine: 82.7707 - val_loss: 0.0346 - val_association_loss: 0.0179 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9803 - val_association_precision: 0.9744 - val_association_recall: 0.9755 - val_location_nzHaversine: 51.4194
# Epoch 38/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0981 - association_loss: 0.0441 - location_loss: 0.0054 - association_nzAccuracy: 0.9723 - association_precision: 0.9510 - association_recall: 0.9570 - location_nzHaversine: 82.6646 - val_loss: 0.0352 - val_association_loss: 0.0180 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9802 - val_association_precision: 0.9727 - val_association_recall: 0.9774 - val_location_nzHaversine: 67.8910
# Epoch 39/400
# 1000/1000 [==============================] - 1193s 1s/step - loss: 0.0980 - association_loss: 0.0443 - location_loss: 0.0054 - association_nzAccuracy: 0.9722 - association_precision: 0.9508 - association_recall: 0.9572 - location_nzHaversine: 82.0835 - val_loss: 0.0337 - val_association_loss: 0.0176 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9805 - val_association_precision: 0.9716 - val_association_recall: 0.9810 - val_location_nzHaversine: 55.4404
# Epoch 40/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0963 - association_loss: 0.0436 - location_loss: 0.0053 - association_nzAccuracy: 0.9726 - association_precision: 0.9514 - association_recall: 0.9578 - location_nzHaversine: 81.3332 - val_loss: 0.0353 - val_association_loss: 0.0186 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9792 - val_association_precision: 0.9716 - val_association_recall: 0.9761 - val_location_nzHaversine: 51.0449
# Saving best model with loss 0.09670756757259369
# Epoch 41/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0972 - association_loss: 0.0438 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9511 - association_recall: 0.9576 - location_nzHaversine: 81.5971 - val_loss: 0.0342 - val_association_loss: 0.0176 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9808 - val_association_precision: 0.9742 - val_association_recall: 0.9772 - val_location_nzHaversine: 58.5261
# Epoch 42/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0977 - association_loss: 0.0439 - location_loss: 0.0054 - association_nzAccuracy: 0.9724 - association_precision: 0.9512 - association_recall: 0.9573 - location_nzHaversine: 82.1567 - val_loss: 0.0326 - val_association_loss: 0.0174 - val_location_loss: 0.0015 - val_association_nzAccuracy: 0.9808 - val_association_precision: 0.9739 - val_association_recall: 0.9771 - val_location_nzHaversine: 45.7687
# Epoch 43/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0976 - association_loss: 0.0438 - location_loss: 0.0054 - association_nzAccuracy: 0.9723 - association_precision: 0.9509 - association_recall: 0.9568 - location_nzHaversine: 82.2154 - val_loss: 0.0363 - val_association_loss: 0.0199 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9787 - val_association_precision: 0.9701 - val_association_recall: 0.9720 - val_location_nzHaversine: 55.5717
# Epoch 44/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0967 - association_loss: 0.0437 - location_loss: 0.0053 - association_nzAccuracy: 0.9725 - association_precision: 0.9514 - association_recall: 0.9575 - location_nzHaversine: 81.8202 - val_loss: 0.0346 - val_association_loss: 0.0182 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9802 - val_association_precision: 0.9714 - val_association_recall: 0.9777 - val_location_nzHaversine: 68.7603
# Epoch 45/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0977 - association_loss: 0.0440 - location_loss: 0.0054 - association_nzAccuracy: 0.9722 - association_precision: 0.9510 - association_recall: 0.9569 - location_nzHaversine: 82.3853 - val_loss: 0.0338 - val_association_loss: 0.0175 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9808 - val_association_precision: 0.9746 - val_association_recall: 0.9760 - val_location_nzHaversine: 57.5067
# Epoch 46/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0979 - association_loss: 0.0442 - location_loss: 0.0054 - association_nzAccuracy: 0.9723 - association_precision: 0.9510 - association_recall: 0.9569 - location_nzHaversine: 81.9915 - val_loss: 0.0357 - val_association_loss: 0.0186 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9792 - val_association_precision: 0.9744 - val_association_recall: 0.9732 - val_location_nzHaversine: 50.0892
# Epoch 47/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0973 - association_loss: 0.0439 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9509 - association_recall: 0.9570 - location_nzHaversine: 81.8401 - val_loss: 0.0341 - val_association_loss: 0.0173 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9811 - val_association_precision: 0.9737 - val_association_recall: 0.9783 - val_location_nzHaversine: 59.3371
# Epoch 48/400
# 1000/1000 [==============================] - 1193s 1s/step - loss: 0.0972 - association_loss: 0.0439 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9514 - association_recall: 0.9576 - location_nzHaversine: 81.7231 - val_loss: 0.0337 - val_association_loss: 0.0173 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9810 - val_association_precision: 0.9748 - val_association_recall: 0.9780 - val_location_nzHaversine: 50.1842
# Epoch 49/400
# 1000/1000 [==============================] - 1193s 1s/step - loss: 0.0976 - association_loss: 0.0441 - location_loss: 0.0054 - association_nzAccuracy: 0.9724 - association_precision: 0.9512 - association_recall: 0.9573 - location_nzHaversine: 81.3996 - val_loss: 0.0341 - val_association_loss: 0.0179 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9803 - val_association_precision: 0.9733 - val_association_recall: 0.9777 - val_location_nzHaversine: 59.5729
# Epoch 50/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0977 - association_loss: 0.0440 - location_loss: 0.0054 - association_nzAccuracy: 0.9723 - association_precision: 0.9511 - association_recall: 0.9570 - location_nzHaversine: 82.1165 - val_loss: 0.0352 - val_association_loss: 0.0181 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9799 - val_association_precision: 0.9726 - val_association_recall: 0.9769 - val_location_nzHaversine: 69.2089
# Epoch 51/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0982 - association_loss: 0.0440 - location_loss: 0.0054 - association_nzAccuracy: 0.9722 - association_precision: 0.9510 - association_recall: 0.9569 - location_nzHaversine: 81.9099 - val_loss: 0.0337 - val_association_loss: 0.0173 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9811 - val_association_precision: 0.9745 - val_association_recall: 0.9778 - val_location_nzHaversine: 72.5147
# Epoch 52/400
# 1000/1000 [==============================] - 1193s 1s/step - loss: 0.0979 - association_loss: 0.0440 - location_loss: 0.0054 - association_nzAccuracy: 0.9723 - association_precision: 0.9510 - association_recall: 0.9569 - location_nzHaversine: 82.2820 - val_loss: 0.0333 - val_association_loss: 0.0173 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9808 - val_association_precision: 0.9738 - val_association_recall: 0.9784 - val_location_nzHaversine: 48.3971
# Epoch 53/400
# 1000/1000 [==============================] - 1193s 1s/step - loss: 0.0970 - association_loss: 0.0440 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9513 - association_recall: 0.9573 - location_nzHaversine: 81.1537 - val_loss: 0.0336 - val_association_loss: 0.0181 - val_location_loss: 0.0015 - val_association_nzAccuracy: 0.9801 - val_association_precision: 0.9728 - val_association_recall: 0.9765 - val_location_nzHaversine: 65.1679
# Epoch 54/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0981 - association_loss: 0.0442 - location_loss: 0.0054 - association_nzAccuracy: 0.9723 - association_precision: 0.9508 - association_recall: 0.9569 - location_nzHaversine: 81.7252 - val_loss: 0.0338 - val_association_loss: 0.0175 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9805 - val_association_precision: 0.9726 - val_association_recall: 0.9807 - val_location_nzHaversine: 63.5837
# Epoch 55/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0975 - association_loss: 0.0438 - location_loss: 0.0054 - association_nzAccuracy: 0.9723 - association_precision: 0.9511 - association_recall: 0.9573 - location_nzHaversine: 81.8004 - val_loss: 0.0357 - val_association_loss: 0.0187 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9797 - val_association_precision: 0.9741 - val_association_recall: 0.9718 - val_location_nzHaversine: 51.6369
# Epoch 56/400
# 1000/1000 [==============================] - 1193s 1s/step - loss: 0.0977 - association_loss: 0.0440 - location_loss: 0.0054 - association_nzAccuracy: 0.9723 - association_precision: 0.9512 - association_recall: 0.9569 - location_nzHaversine: 81.7577 - val_loss: 0.0350 - val_association_loss: 0.0181 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9799 - val_association_precision: 0.9736 - val_association_recall: 0.9774 - val_location_nzHaversine: 75.5098
# Epoch 57/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0976 - association_loss: 0.0439 - location_loss: 0.0054 - association_nzAccuracy: 0.9724 - association_precision: 0.9512 - association_recall: 0.9576 - location_nzHaversine: 81.7899 - val_loss: 0.0346 - val_association_loss: 0.0178 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9805 - val_association_precision: 0.9722 - val_association_recall: 0.9795 - val_location_nzHaversine: 64.6400
# Epoch 58/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0976 - association_loss: 0.0439 - location_loss: 0.0054 - association_nzAccuracy: 0.9724 - association_precision: 0.9511 - association_recall: 0.9573 - location_nzHaversine: 81.3990 - val_loss: 0.0347 - val_association_loss: 0.0190 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9790 - val_association_precision: 0.9726 - val_association_recall: 0.9759 - val_location_nzHaversine: 60.8071
# Epoch 59/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0977 - association_loss: 0.0440 - location_loss: 0.0054 - association_nzAccuracy: 0.9723 - association_precision: 0.9511 - association_recall: 0.9568 - location_nzHaversine: 82.0563 - val_loss: 0.0345 - val_association_loss: 0.0182 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9798 - val_association_precision: 0.9730 - val_association_recall: 0.9775 - val_location_nzHaversine: 63.0326
# Epoch 60/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0972 - association_loss: 0.0437 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9512 - association_recall: 0.9577 - location_nzHaversine: 81.5722 - val_loss: 0.0346 - val_association_loss: 0.0176 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9805 - val_association_precision: 0.9725 - val_association_recall: 0.9790 - val_location_nzHaversine: 57.1575
# Epoch 61/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0981 - association_loss: 0.0440 - location_loss: 0.0054 - association_nzAccuracy: 0.9722 - association_precision: 0.9511 - association_recall: 0.9566 - location_nzHaversine: 81.5113 - val_loss: 0.0362 - val_association_loss: 0.0190 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9791 - val_association_precision: 0.9741 - val_association_recall: 0.9734 - val_location_nzHaversine: 65.0192
# Epoch 62/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0974 - association_loss: 0.0437 - location_loss: 0.0054 - association_nzAccuracy: 0.9724 - association_precision: 0.9514 - association_recall: 0.9575 - location_nzHaversine: 81.6086 - val_loss: 0.0339 - val_association_loss: 0.0182 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9795 - val_association_precision: 0.9750 - val_association_recall: 0.9751 - val_location_nzHaversine: 61.1466
# Epoch 63/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0991 - association_loss: 0.0444 - location_loss: 0.0055 - association_nzAccuracy: 0.9720 - association_precision: 0.9507 - association_recall: 0.9565 - location_nzHaversine: 83.1606 - val_loss: 0.0329 - val_association_loss: 0.0170 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9813 - val_association_precision: 0.9728 - val_association_recall: 0.9798 - val_location_nzHaversine: 48.3702
# Epoch 64/400
# 1000/1000 [==============================] - 1193s 1s/step - loss: 0.0979 - association_loss: 0.0440 - location_loss: 0.0054 - association_nzAccuracy: 0.9723 - association_precision: 0.9509 - association_recall: 0.9572 - location_nzHaversine: 81.4603 - val_loss: 0.0342 - val_association_loss: 0.0176 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9804 - val_association_precision: 0.9714 - val_association_recall: 0.9797 - val_location_nzHaversine: 68.3847
# Epoch 65/400
# 1000/1000 [==============================] - 1193s 1s/step - loss: 0.0982 - association_loss: 0.0440 - location_loss: 0.0054 - association_nzAccuracy: 0.9722 - association_precision: 0.9509 - association_recall: 0.9570 - location_nzHaversine: 82.2669 - val_loss: 0.0337 - val_association_loss: 0.0175 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9809 - val_association_precision: 0.9744 - val_association_recall: 0.9777 - val_location_nzHaversine: 54.2129
# Epoch 66/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0977 - association_loss: 0.0439 - location_loss: 0.0054 - association_nzAccuracy: 0.9722 - association_precision: 0.9510 - association_recall: 0.9568 - location_nzHaversine: 82.2286 - val_loss: 0.0335 - val_association_loss: 0.0178 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9806 - val_association_precision: 0.9731 - val_association_recall: 0.9771 - val_location_nzHaversine: 59.3777
# Epoch 67/400
# 1000/1000 [==============================] - 1193s 1s/step - loss: 0.0975 - association_loss: 0.0440 - location_loss: 0.0053 - association_nzAccuracy: 0.9723 - association_precision: 0.9513 - association_recall: 0.9572 - location_nzHaversine: 81.1873 - val_loss: 0.0335 - val_association_loss: 0.0173 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9810 - val_association_precision: 0.9728 - val_association_recall: 0.9794 - val_location_nzHaversine: 64.4101
# Epoch 68/400
# 1000/1000 [==============================] - 1193s 1s/step - loss: 0.0982 - association_loss: 0.0440 - location_loss: 0.0054 - association_nzAccuracy: 0.9722 - association_precision: 0.9508 - association_recall: 0.9567 - location_nzHaversine: 82.4109 - val_loss: 0.0330 - val_association_loss: 0.0173 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9811 - val_association_precision: 0.9731 - val_association_recall: 0.9794 - val_location_nzHaversine: 60.1144
# Epoch 69/400
# 1000/1000 [==============================] - 1193s 1s/step - loss: 0.0972 - association_loss: 0.0439 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9510 - association_recall: 0.9571 - location_nzHaversine: 81.1943 - val_loss: 0.0330 - val_association_loss: 0.0175 - val_location_loss: 0.0015 - val_association_nzAccuracy: 0.9807 - val_association_precision: 0.9765 - val_association_recall: 0.9756 - val_location_nzHaversine: 44.1943
# Epoch 70/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0970 - association_loss: 0.0439 - location_loss: 0.0053 - association_nzAccuracy: 0.9725 - association_precision: 0.9516 - association_recall: 0.9574 - location_nzHaversine: 80.7207 - val_loss: 0.0336 - val_association_loss: 0.0177 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9802 - val_association_precision: 0.9745 - val_association_recall: 0.9774 - val_location_nzHaversine: 47.7347
# Epoch 71/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0972 - association_loss: 0.0439 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9510 - association_recall: 0.9575 - location_nzHaversine: 81.1659 - val_loss: 0.0341 - val_association_loss: 0.0183 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9797 - val_association_precision: 0.9732 - val_association_recall: 0.9759 - val_location_nzHaversine: 50.9254
# Saving best model with loss 0.09670350700616837
# Epoch 72/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0970 - association_loss: 0.0440 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9513 - association_recall: 0.9575 - location_nzHaversine: 80.7123 - val_loss: 0.0339 - val_association_loss: 0.0181 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9801 - val_association_precision: 0.9722 - val_association_recall: 0.9780 - val_location_nzHaversine: 56.0237
# Epoch 73/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0968 - association_loss: 0.0436 - location_loss: 0.0053 - association_nzAccuracy: 0.9726 - association_precision: 0.9515 - association_recall: 0.9576 - location_nzHaversine: 81.7301 - val_loss: 0.0340 - val_association_loss: 0.0179 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9807 - val_association_precision: 0.9745 - val_association_recall: 0.9746 - val_location_nzHaversine: 65.3075
# Epoch 74/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0977 - association_loss: 0.0439 - location_loss: 0.0054 - association_nzAccuracy: 0.9723 - association_precision: 0.9511 - association_recall: 0.9572 - location_nzHaversine: 81.4108 - val_loss: 0.0329 - val_association_loss: 0.0173 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9813 - val_association_precision: 0.9726 - val_association_recall: 0.9784 - val_location_nzHaversine: 52.0021
# Epoch 75/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0978 - association_loss: 0.0440 - location_loss: 0.0054 - association_nzAccuracy: 0.9722 - association_precision: 0.9510 - association_recall: 0.9569 - location_nzHaversine: 81.8975 - val_loss: 0.0339 - val_association_loss: 0.0175 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9809 - val_association_precision: 0.9731 - val_association_recall: 0.9781 - val_location_nzHaversine: 61.4216
# Epoch 76/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0976 - association_loss: 0.0441 - location_loss: 0.0053 - association_nzAccuracy: 0.9723 - association_precision: 0.9509 - association_recall: 0.9571 - location_nzHaversine: 81.7401 - val_loss: 0.0323 - val_association_loss: 0.0166 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9818 - val_association_precision: 0.9732 - val_association_recall: 0.9813 - val_location_nzHaversine: 56.4137
# Epoch 77/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0962 - association_loss: 0.0435 - location_loss: 0.0053 - association_nzAccuracy: 0.9726 - association_precision: 0.9515 - association_recall: 0.9575 - location_nzHaversine: 81.4632 - val_loss: 0.0339 - val_association_loss: 0.0173 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9807 - val_association_precision: 0.9736 - val_association_recall: 0.9796 - val_location_nzHaversine: 75.6015
# Saving best model with loss 0.09651552885770798
# Epoch 78/400
# ...
# Epoch 94/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0974 - association_loss: 0.0441 - location_loss: 0.0053 - association_nzAccuracy: 0.9723 - association_precision: 0.9510 - association_recall: 0.9570 - location_nzHaversine: 81.8531 - val_loss: 0.0345 - val_association_loss: 0.0181 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9801 - val_association_precision: 0.9747 - val_association_recall: 0.9758 - val_location_nzHaversine: 55.9589
# Epoch 95/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0968 - association_loss: 0.0436 - location_loss: 0.0053 - association_nzAccuracy: 0.9725 - association_precision: 0.9515 - association_recall: 0.9571 - location_nzHaversine: 81.6473 - val_loss: 0.0335 - val_association_loss: 0.0172 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9811 - val_association_precision: 0.9733 - val_association_recall: 0.9793 - val_location_nzHaversine: 71.7390
# Epoch 96/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0967 - association_loss: 0.0436 - location_loss: 0.0053 - association_nzAccuracy: 0.9725 - association_precision: 0.9517 - association_recall: 0.9573 - location_nzHaversine: 81.3355 - val_loss: 0.0348 - val_association_loss: 0.0176 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9807 - val_association_precision: 0.9715 - val_association_recall: 0.9802 - val_location_nzHaversine: 50.8719
# Epoch 97/400
# 1000/1000 [==============================] - 1193s 1s/step - loss: 0.0974 - association_loss: 0.0439 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9511 - association_recall: 0.9572 - location_nzHaversine: 81.6859 - val_loss: 0.0343 - val_association_loss: 0.0184 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9796 - val_association_precision: 0.9753 - val_association_recall: 0.9742 - val_location_nzHaversine: 66.3821
# Epoch 98/400
# 1000/1000 [==============================] - 1193s 1s/step - loss: 0.0973 - association_loss: 0.0440 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9512 - association_recall: 0.9572 - location_nzHaversine: 82.0392 - val_loss: 0.0338 - val_association_loss: 0.0173 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9811 - val_association_precision: 0.9714 - val_association_recall: 0.9822 - val_location_nzHaversine: 63.7788
# Epoch 99/400
# 1000/1000 [==============================] - 1193s 1s/step - loss: 0.0979 - association_loss: 0.0441 - location_loss: 0.0054 - association_nzAccuracy: 0.9721 - association_precision: 0.9509 - association_recall: 0.9569 - location_nzHaversine: 82.5201 - val_loss: 0.0347 - val_association_loss: 0.0182 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9798 - val_association_precision: 0.9708 - val_association_recall: 0.9799 - val_location_nzHaversine: 63.5358
# Epoch 100/400
# 1000/1000 [==============================] - 1193s 1s/step - loss: 0.0972 - association_loss: 0.0440 - location_loss: 0.0053 - association_nzAccuracy: 0.9723 - association_precision: 0.9511 - association_recall: 0.9572 - location_nzHaversine: 81.5228 - val_loss: 0.0330 - val_association_loss: 0.0174 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9806 - val_association_precision: 0.9723 - val_association_recall: 0.9810 - val_location_nzHaversine: 50.5859
# Epoch 101/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0974 - association_loss: 0.0438 - location_loss: 0.0054 - association_nzAccuracy: 0.9724 - association_precision: 0.9515 - association_recall: 0.9574 - location_nzHaversine: 81.7224 - val_loss: 0.0350 - val_association_loss: 0.0183 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9797 - val_association_precision: 0.9732 - val_association_recall: 0.9760 - val_location_nzHaversine: 59.5626
# Epoch 102/400
# 1000/1000 [==============================] - 1193s 1s/step - loss: 0.0969 - association_loss: 0.0438 - location_loss: 0.0053 - association_nzAccuracy: 0.9725 - association_precision: 0.9514 - association_recall: 0.9577 - location_nzHaversine: 81.7486 - val_loss: 0.0352 - val_association_loss: 0.0183 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9803 - val_association_precision: 0.9690 - val_association_recall: 0.9784 - val_location_nzHaversine: 54.4412
# Epoch 103/400
# 1000/1000 [==============================] - 1193s 1s/step - loss: 0.0976 - association_loss: 0.0439 - location_loss: 0.0054 - association_nzAccuracy: 0.9723 - association_precision: 0.9514 - association_recall: 0.9571 - location_nzHaversine: 82.2235 - val_loss: 0.0340 - val_association_loss: 0.0179 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9799 - val_association_precision: 0.9727 - val_association_recall: 0.9781 - val_location_nzHaversine: 74.5986
# Epoch 104/400
# 1000/1000 [==============================] - 1193s 1s/step - loss: 0.0970 - association_loss: 0.0437 - location_loss: 0.0053 - association_nzAccuracy: 0.9725 - association_precision: 0.9514 - association_recall: 0.9574 - location_nzHaversine: 82.0836 - val_loss: 0.0342 - val_association_loss: 0.0178 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9805 - val_association_precision: 0.9726 - val_association_recall: 0.9770 - val_location_nzHaversine: 51.0308
# Epoch 105/400
# 1000/1000 [==============================] - 1192s 1s/step - loss: 0.0970 - association_loss: 0.0437 - location_loss: 0.0053 - association_nzAccuracy: 0.9725 - association_precision: 0.9516 - association_recall: 0.9571 - location_nzHaversine: 81.5922 - val_loss: 0.0351 - val_association_loss: 0.0183 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9799 - val_association_precision: 0.9723 - val_association_recall: 0.9764 - val_location_nzHaversine: 58.1807
# Epoch 106/400
# 1000/1000 [==============================] - 1192s 1s/step - loss: 0.0975 - association_loss: 0.0440 - location_loss: 0.0053 - association_nzAccuracy: 0.9723 - association_precision: 0.9512 - association_recall: 0.9572 - location_nzHaversine: 81.6779 - val_loss: 0.0339 - val_association_loss: 0.0181 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9797 - val_association_precision: 0.9729 - val_association_recall: 0.9777 - val_location_nzHaversine: 55.3490
# Epoch 107/400
# 1000/1000 [==============================] - 1192s 1s/step - loss: 0.0968 - association_loss: 0.0436 - location_loss: 0.0053 - association_nzAccuracy: 0.9726 - association_precision: 0.9517 - association_recall: 0.9574 - location_nzHaversine: 81.5925 - val_loss: 0.0366 - val_association_loss: 0.0184 - val_location_loss: 0.0018 - val_association_nzAccuracy: 0.9793 - val_association_precision: 0.9727 - val_association_recall: 0.9772 - val_location_nzHaversine: 57.4168
# Epoch 108/400
# 1000/1000 [==============================] - 1193s 1s/step - loss: 0.0967 - association_loss: 0.0438 - location_loss: 0.0053 - association_nzAccuracy: 0.9726 - association_precision: 0.9518 - association_recall: 0.9579 - location_nzHaversine: 81.9492 - val_loss: 0.0346 - val_association_loss: 0.0185 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9796 - val_association_precision: 0.9718 - val_association_recall: 0.9752 - val_location_nzHaversine: 58.7792
# Epoch 109/400
# 1000/1000 [==============================] - 1193s 1s/step - loss: 0.0974 - association_loss: 0.0440 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9513 - association_recall: 0.9570 - location_nzHaversine: 81.2833 - val_loss: 0.0348 - val_association_loss: 0.0179 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9803 - val_association_precision: 0.9743 - val_association_recall: 0.9761 - val_location_nzHaversine: 52.3102
# Epoch 110/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0967 - association_loss: 0.0436 - location_loss: 0.0053 - association_nzAccuracy: 0.9725 - association_precision: 0.9515 - association_recall: 0.9574 - location_nzHaversine: 81.4438 - val_loss: 0.0333 - val_association_loss: 0.0176 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9802 - val_association_precision: 0.9727 - val_association_recall: 0.9788 - val_location_nzHaversine: 51.0229
# Epoch 111/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0974 - association_loss: 0.0440 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9512 - association_recall: 0.9571 - location_nzHaversine: 80.2832 - val_loss: 0.0337 - val_association_loss: 0.0175 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9806 - val_association_precision: 0.9745 - val_association_recall: 0.9785 - val_location_nzHaversine: 55.9747
# Epoch 112/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0972 - association_loss: 0.0440 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9515 - association_recall: 0.9574 - location_nzHaversine: 80.3022 - val_loss: 0.0341 - val_association_loss: 0.0179 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9806 - val_association_precision: 0.9725 - val_association_recall: 0.9781 - val_location_nzHaversine: 59.0343
# Epoch 113/400
# 1000/1000 [==============================] - 1194s 1s/step - loss: 0.0974 - association_loss: 0.0441 - location_loss: 0.0053 - association_nzAccuracy: 0.9724 - association_precision: 0.9513 - association_recall: 0.9573 - location_nzHaversine: 80.3864 - val_loss: 0.0334 - val_association_loss: 0.0175 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9806 - val_association_precision: 0.9723 - val_association_recall: 0.9791 - val_location_nzHaversine: 50.9342
# Epoch 114/400
# 1000/1000 [==============================] - 1192s 1s/step - loss: 0.0976 - association_loss: 0.0440 - location_loss: 0.0054 - association_nzAccuracy: 0.9724 - association_precision: 0.9513 - association_recall: 0.9574 - location_nzHaversine: 81.0329 - val_loss: 0.0352 - val_association_loss: 0.0192 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9793 - val_association_precision: 0.9708 - val_association_recall: 0.9734 - val_location_nzHaversine: 57.0380
# Epoch 115/400
# 1000/1000 [==============================] - 1192s 1s/step - loss: 0.0968 - association_loss: 0.0438 - location_loss: 0.0053 - association_nzAccuracy: 0.9725 - association_precision: 0.9514 - association_recall: 0.9575 - location_nzHaversine: 81.1913 - val_loss: 0.0335 - val_association_loss: 0.0173 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9810 - val_association_precision: 0.9723 - val_association_recall: 0.9803 - val_location_nzHaversine: 46.3689
# Epoch 116/400
# 1000/1000 [==============================] - 1192s 1s/step - loss: 0.0977 - association_loss: 0.0438 - location_loss: 0.0054 - association_nzAccuracy: 0.9724 - association_precision: 0.9513 - association_recall: 0.9573 - location_nzHaversine: 81.4727 - val_loss: 0.0356 - val_association_loss: 0.0191 - val_location_loss: 0.0016 - val_association_nzAccuracy: 0.9792 - val_association_precision: 0.9722 - val_association_recall: 0.9733 - val_location_nzHaversine: 50.3230
# Epoch 117/400
# 1000/1000 [==============================] - 1192s 1s/step - loss: 0.0966 - association_loss: 0.0437 - location_loss: 0.0053 - association_nzAccuracy: 0.9725 - association_precision: 0.9515 - association_recall: 0.9574 - location_nzHaversine: 80.4105 - val_loss: 0.0351 - val_association_loss: 0.0180 - val_location_loss: 0.0017 - val_association_nzAccuracy: 0.9801 - val_association_precision: 0.9723 - val_association_recall: 0.9782 - val_location_nzHaversine: 49.1001
# [(   0.,  0.04348646,  0.97258425,  0.9515695 ,  0.95773441,  0.00533248,  80.95800018,  0.09681124,  0.01722382,  0.98111528,  0.97375083,  0.97879463,  0.00161922,  77.28030396,  0.03341598) (   1.,  0.04405447,  0.97237808,  0.95122468,  0.95721352,  0.00532078,  81.29206085,  0.09726227,  0.01794953,  0.98027104,  0.97478139,  0.97458827,  0.00164535,  45.88268661,  0.034403  ) (   2.,  0.04398881,  0.97231609,  0.95125616,  0.95717376,  0.0053551 ,  82.03106689,  0.09753975,  0.01791651,  0.98002112,  0.97457999,  0.97662765,  0.00158806,  50.78209305,  0.03379716) (   3.,  0.04406167,  0.97233349,  0.95117974,  0.95717555,  0.00533815,  82.01786041,  0.09744316,  0.01856913,  0.97960687,  0.97363573,  0.97392905,  0.00165463,  55.73839951,  0.0351154 ) (   4.,  0.04418601,  0.97217947,  0.95086747,  0.95676738,  0.00540836,  82.64198303,  0.09826966,  0.01702824,  0.98133516,  0.97128403,  0.98062897,  0.00152072,  71.23069763,  0.03223549) (   5.,  0.04402137,  0.97235149,  0.95104468,  0.95720416,  0.00531783,  81.34314728,  0.09719966,  0.01725396,  0.98126835,  0.97436172,  0.97924131,  0.00170341,  54.54429626,  0.03428807) (   6.,  0.04415339,  0.97222185,  0.95087302,  0.95683151,  0.0053737 ,  82.11274719,  0.09789039,  0.01852609,  0.98032027,  0.97093093,  0.97453582,  0.00151582,  51.29542923,  0.0336843 ) (   7.,  0.04405093,  0.97225255,  0.95078629,  0.95701504,  0.00539664,  82.55587769,  0.09801728,  0.01857045,  0.98010117,  0.97338063,  0.97106999,  0.00163065,  58.23216629,  0.03487692) (   8.,  0.04397199,  0.97220135,  0.95084089,  0.95689189,  0.00540438,  83.43910217,  0.09801581,  0.01766864,  0.98033863,  0.97436273,  0.97696632,  0.00171428,  62.70843124,  0.03481148) (   9.,  0.04429517,  0.97212023,  0.95043325,  0.95665801,  0.00540167,  82.35897827,  0.0983118 ,  0.01748898,  0.98088968,  0.97515744,  0.9763965 ,  0.00184156,  87.55944824,  0.03590455) (  10.,  0.0440855 ,  0.97235537,  0.95125943,  0.95732731,  0.00533619,  82.11534119,  0.09744743,  0.01717625,  0.98114681,  0.97234726,  0.97970921,  0.00159694,  47.73409271,  0.03314562) (  11.,  0.04422953,  0.97217554,  0.95076221,  0.95692939,  0.00539605,  82.89897156,  0.09818999,  0.0187638 ,  0.97967088,  0.97141087,  0.97398448,  0.00157783,  48.2039032 ,  0.03454214) (  12.,  0.04391592,  0.97248566,  0.95136523,  0.95729744,  0.00533464,  81.56089783,  0.09726232,  0.01785604,  0.980582  ,  0.97388673,  0.97661138,  0.00159978,  55.44238663,  0.03385382) (  13.,  0.04383738,  0.97239584,  0.95128614,  0.95735061,  0.00535405,  82.05243683,  0.09737795,  0.01819139,  0.97956705,  0.9746291 ,  0.97550261,  0.00176034,  72.00632477,  0.03579482) (  14.,  0.04404715,  0.97231495,  0.95098537,  0.95742714,  0.00537749,  82.74917603,  0.09782209,  0.01821013,  0.97969913,  0.97404683,  0.97550583,  0.00169618,  63.04201889,  0.03517188) (  15.,  0.04396138,  0.97234797,  0.95126307,  0.95743674,  0.00535675,  81.6257019 ,  0.09752887,  0.0178348 ,  0.98021591,  0.97199744,  0.97870147,  0.00160975,  54.68328476,  0.03393225) (  16.,  0.04379038,  0.97249788,  0.95120716,  0.95725274,  0.00532677,  81.27059937,  0.09705807,  0.01750014,  0.98093134,  0.97533655,  0.97588134,  0.00168271,  54.4912262 ,  0.03432726) (  17.,  0.04390401,  0.97248143,  0.95131868,  0.95727175,  0.0053299 ,  81.60713196,  0.09720302,  0.01764636,  0.98107708,  0.97160107,  0.9790315 ,  0.00162304,  61.65815353,  0.03387674) (  18.,  0.04406742,  0.97234696,  0.9509604 ,  0.95716429,  0.00534825,  81.57403564,  0.09754997,  0.01737875,  0.98136997,  0.97298735,  0.97792298,  0.00174522,  57.7360611 ,  0.03483092) (  19.,  0.04379372,  0.97239578,  0.9513005 ,  0.95729989,  0.00536602,  81.68341064,  0.09745389,  0.018793  ,  0.9791289 ,  0.97409987,  0.97372323,  0.0017738 ,  58.6206398 ,  0.03653102) (  20.,  0.04398742,  0.97235405,  0.95108503,  0.95701122,  0.00536535,  81.98544312,  0.09764083,  0.01836031,  0.98004878,  0.97172618,  0.9763692 ,  0.0015 ...
